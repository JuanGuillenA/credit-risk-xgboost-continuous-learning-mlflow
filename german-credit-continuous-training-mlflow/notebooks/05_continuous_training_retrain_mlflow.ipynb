# %%
import os, json, time
import pandas as pd
import joblib

from datetime import datetime
import mlflow
import mlflow.sklearn
from xgboost import XGBClassifier

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score

# =========================
# Config
# =========================
mlflow.set_tracking_uri("file:./mlruns")
mlflow.set_experiment("CooperativeCreditRisk-XGBoost")

os.makedirs("../artifacts/models", exist_ok=True)
os.makedirs("../artifacts/reports", exist_ok=True)

FEATURES = [
    "duration","credit_amount","age",
    "checking_status","employment","savings_status","purpose"
]
TARGET = "target"

fixed_test_path   = "../artifacts/dataset/fixed_test.csv"
base50_path       = "../artifacts/dataset/initial_base_50.csv"
future_pool_path  = "../artifacts/dataset/future_pool.csv"
feedback_path     = "../artifacts/dataset/feedback_new_data.csv"  # igual que app
registry_path     = "../artifacts/models/model_registry.json"

batch_size = 10

def log(msg):
    ts = datetime.now().strftime("%H:%M:%S")
    print(f"[{ts}] {msg}", flush=True)

def ensure_cols(df, cols, name):
    miss = [c for c in cols if c not in df.columns]
    if miss:
        raise ValueError(f"{name}: faltan columnas {miss}")

def evaluate(model, X_eval, y_eval):
    proba = model.predict_proba(X_eval)[:, 1]
    pred = (proba >= 0.5).astype(int)
    return {
        "accuracy": float(accuracy_score(y_eval, pred)),
        "f1": float(f1_score(y_eval, pred)),
        "precision": float(precision_score(y_eval, pred)),
        "recall": float(recall_score(y_eval, pred)),
        "roc_auc": float(roc_auc_score(y_eval, proba)),
    }

# =========================
# Load fixed test
# =========================
if not os.path.exists(fixed_test_path):
    raise FileNotFoundError(f"fixed_test no encontrado: {fixed_test_path}")

fixed_test = pd.read_csv(fixed_test_path)
ensure_cols(fixed_test, FEATURES + [TARGET], "fixed_test")
fixed_test[TARGET] = fixed_test[TARGET].astype(int)

X_test = fixed_test[FEATURES].copy()
y_test = fixed_test[TARGET].copy()

# =========================
# Load base50
# =========================
base50 = pd.read_csv(base50_path)
ensure_cols(base50, FEATURES + [TARGET], "base50")
base50[TARGET] = base50[TARGET].astype(int)

# =========================
# Load future_pool + take batch
# =========================
future_pool = pd.read_csv(future_pool_path)
ensure_cols(future_pool, FEATURES + [TARGET], "future_pool")
future_pool[TARGET] = future_pool[TARGET].astype(int)

take_n = min(batch_size, len(future_pool))
if take_n == 0:
    batch = future_pool.copy()
    future_remaining = future_pool.copy()
else:
    batch = future_pool.sample(take_n, random_state=7)
    future_remaining = future_pool.drop(batch.index)

# persist remaining
future_remaining.to_csv(future_pool_path, index=False)

# =========================
# Load feedback (from app)
# =========================
if os.path.exists(feedback_path):
    feedback = pd.read_csv(feedback_path)
    ensure_cols(feedback, FEATURES + [TARGET], "feedback")
    feedback[TARGET] = feedback[TARGET].astype(int)
else:
    feedback = pd.DataFrame(columns=FEATURES + [TARGET])

log(f"Base50 rows: {len(base50)}")
log(f"Future pool before: {len(future_pool)}")
log(f"Batch taken: {len(batch)}")
log(f"Future pool after: {len(future_remaining)}")
log(f"Feedback rows: {len(feedback)}")

# =========================
# Train set: base50 + batch + feedback
# =========================
train_plus = pd.concat([base50, batch, feedback], ignore_index=True)
ensure_cols(train_plus, FEATURES + [TARGET], "train_plus")

X_train = train_plus[FEATURES].copy()
y_train = train_plus[TARGET].astype(int).copy()

log(f"Train total rows: {len(train_plus)}")
log(f"Fixed test rows: {len(X_test)}")

# =========================
# Pipeline
# =========================
cat_cols = ["checking_status","employment","savings_status","purpose"]
num_cols = ["duration","credit_amount","age"]

preprocess = ColumnTransformer(
    transformers=[
        ("num", Pipeline([("imputer", SimpleImputer(strategy="median"))]), num_cols),
        ("cat", Pipeline([
            ("imputer", SimpleImputer(strategy="most_frequent")),
            ("onehot", OneHotEncoder(handle_unknown="ignore"))
        ]), cat_cols)
    ],
    remainder="drop"
)

xgb = XGBClassifier(
    n_estimators=450,
    max_depth=4,
    learning_rate=0.05,
    subsample=0.90,
    colsample_bytree=0.90,
    random_state=42,
    n_jobs=-1,
    eval_metric="logloss",
    verbosity=1
)

pipe = Pipeline([("preprocess", preprocess), ("model", xgb)])

# version name
version = "v_" + datetime.utcnow().strftime("%Y%m%d_%H%M%S")

# =========================
# Train with visible progress
# =========================
with mlflow.start_run(run_name=f"retrain_{version}") as run:
    t0 = time.time()

    log("Training start (with XGBoost verbose eval)...")

    # transform first to pass eval_set to XGBClassifier
    pre = pipe.named_steps["preprocess"]
    model = pipe.named_steps["model"]

    Xtr = pre.fit_transform(X_train)
    Xev = pre.transform(X_test)

    model.fit(
        Xtr, y_train,
        eval_set=[(Xev, y_test)],
        verbose=True
    )

    log(f"Training finished in {time.time() - t0:.2f}s")

    metrics = evaluate(pipe, X_test, y_test)

    mlflow.log_param("deployment_version", version)
    mlflow.log_param("batch_size_used", int(len(batch)))
    mlflow.log_param("future_pool_remaining", int(len(future_remaining)))
    mlflow.log_param("base_rows", int(len(base50)))
    mlflow.log_param("feedback_rows", int(len(feedback)))
    mlflow.log_param("train_total_rows", int(len(train_plus)))
    mlflow.log_param("test_rows_fixed", int(len(X_test)))

    for k, v in metrics.items():
        mlflow.log_metric(k, v)

    model_path = f"../artifacts/models/model_{version}.joblib"
    joblib.dump(pipe, model_path)

    metrics_path = f"../artifacts/reports/metrics_{version}.json"
    with open(metrics_path, "w") as f:
        json.dump(metrics, f, indent=2)

    mlflow.log_artifact(model_path, artifact_path="model_joblib")
    mlflow.log_artifact(metrics_path, artifact_path="reports")
    mlflow.sklearn.log_model(
    pipe,
    artifact_path="sklearn_model",
    registered_model_name="CooperativeCreditRisk-XGBoost"
)


log("New version: " + version)
log("Metrics: " + str(metrics))

# =========================
# Update registry
# =========================
with open(registry_path, "r") as f:
    registry = json.load(f)

registry["current_version"] = version
registry["models"][version] = {
    "path": f"artifacts/models/model_{version}.joblib",
    "metrics_path": f"artifacts/reports/metrics_{version}.json"
}

with open(registry_path, "w") as f:
    json.dump(registry, f, indent=2)

log("Updated registry: " + registry_path)
# Out:
# [15:30:29] Base50 rows: 50
# [15:30:29] Future pool before: 340
# [15:30:29] Batch taken: 10
# [15:30:29] Future pool after: 330
# [15:30:29] Feedback rows: 7
# [15:30:29] Train total rows: 67
# [15:30:29] Fixed test rows: 250
# [15:30:29] Training start (with XGBoost verbose eval)...
# [0]	validation_0-logloss:0.60796
# [1]	validation_0-logloss:0.60365
# [2]	validation_0-logloss:0.60065
# [3]	validation_0-logloss:0.59878
# [4]	validation_0-logloss:0.59757
# [5]	validation_0-logloss:0.59668
# [6]	validation_0-logloss:0.59672
# [7]	validation_0-logloss:0.59508
# [8]	validation_0-logloss:0.59294
# [9]	validation_0-logloss:0.59172
# [10]	validation_0-logloss:0.59176
# [11]	validation_0-logloss:0.59091
# [12]	validation_0-logloss:0.59158
# [13]	validation_0-logloss:0.59036
# [14]	validation_0-logloss:0.59020
# [15]	validation_0-logloss:0.59109
# [16]	validation_0-logloss:0.59046
# [17]	validation_0-logloss:0.59116
# [18]	validation_0-logloss:0.59203
# [19]	validation_0-logloss:0.59293
# [20]	validation_0-logloss:0.59325
# [21]	validation_0-logloss:0.59348
# [22]	validation_0-logloss:0.59293
# [23]	validation_0-logloss:0.59350
# [24]	validation_0-logloss:0.59405
# [25]	validation_0-logloss:0.59551
# [26]	validation_0-logloss:0.59636
# [27]	validation_0-logloss:0.59837
# [28]	validation_0-logloss:0.59968
# [29]	validation_0-logloss:0.59961
# [30]	validation_0-logloss:0.59816
# [31]	validation_0-logloss:0.59892
# [32]	validation_0-logloss:0.59898
# [33]	validation_0-logloss:0.59995
# [34]	validation_0-logloss:0.59838
# [35]	validation_0-logloss:0.59954
# [36]	validation_0-logloss:0.59939
# [37]	validation_0-logloss:0.60046
# [38]	validation_0-logloss:0.60049
# [39]	validation_0-logloss:0.60218
# [40]	validation_0-logloss:0.60240
# [41]	validation_0-logloss:0.60081
# [42]	validation_0-logloss:0.60114
# [43]	validation_0-logloss:0.60231
# [44]	validation_0-logloss:0.60343
# [45]	validation_0-logloss:0.60493
# [46]	validation_0-logloss:0.60588
# [47]	validation_0-logloss:0.60641
# [48]	validation_0-logloss:0.60748
# [49]	validation_0-logloss:0.60777
# [50]	validation_0-logloss:0.60955
# [51]	validation_0-logloss:0.61103
# [52]	validation_0-logloss:0.61275
# [53]	validation_0-logloss:0.61301
# [54]	validation_0-logloss:0.61242
# [55]	validation_0-logloss:0.61306
# [56]	validation_0-logloss:0.61333
# [57]	validation_0-logloss:0.61322
# [58]	validation_0-logloss:0.61385
# [59]	validation_0-logloss:0.61453
# [60]	validation_0-logloss:0.61616
# [61]	validation_0-logloss:0.61765
# [62]	validation_0-logloss:0.61823
# [63]	validation_0-logloss:0.62030
# [64]	validation_0-logloss:0.61941
# [65]	validation_0-logloss:0.62099
# [66]	validation_0-logloss:0.62239
# [67]	validation_0-logloss:0.62342
# [68]	validation_0-logloss:0.62531
# [69]	validation_0-logloss:0.62565
# [70]	validation_0-logloss:0.62707
# [71]	validation_0-logloss:0.62941
# [72]	validation_0-logloss:0.63108
# [73]	validation_0-logloss:0.63253
# [74]	validation_0-logloss:0.63141
# [75]	validation_0-logloss:0.63195
# [76]	validation_0-logloss:0.63178
# [77]	validation_0-logloss:0.63230
# [78]	validation_0-logloss:0.63290
# [79]	validation_0-logloss:0.63428
# [80]	validation_0-logloss:0.63457
# [81]	validation_0-logloss:0.63450
# [82]	validation_0-logloss:0.63451
# [83]	validation_0-logloss:0.63581
# [84]	validation_0-logloss:0.63640
# [85]	validation_0-logloss:0.63752
# [86]	validation_0-logloss:0.63904
# [87]	validation_0-logloss:0.64125
# [88]	validation_0-logloss:0.64231
# [89]	validation_0-logloss:0.64309
# [90]	validation_0-logloss:0.64333
# [91]	validation_0-logloss:0.64463
# [92]	validation_0-logloss:0.64541
# [93]	validation_0-logloss:0.64711
# [94]	validation_0-logloss:0.64819
# [95]	validation_0-logloss:0.64977
# [96]	validation_0-logloss:0.65074
# [97]	validation_0-logloss:0.65191
# [98]	validation_0-logloss:0.65341
# [99]	validation_0-logloss:0.65255
# [100]	validation_0-logloss:0.65323
# [101]	validation_0-logloss:0.65479
# [102]	validation_0-logloss:0.65534
# [103]	validation_0-logloss:0.65619
# [104]	validation_0-logloss:0.65827
# [105]	validation_0-logloss:0.65860
# [106]	validation_0-logloss:0.65823
# [107]	validation_0-logloss:0.65839
# [108]	validation_0-logloss:0.66009
# [109]	validation_0-logloss:0.66119
# [110]	validation_0-logloss:0.66199
# [111]	validation_0-logloss:0.66360
# [112]	validation_0-logloss:0.66421
# [113]	validation_0-logloss:0.66489
# [114]	validation_0-logloss:0.66591
# [115]	validation_0-logloss:0.66651
# [116]	validation_0-logloss:0.66756
# [117]	validation_0-logloss:0.66864
# [118]	validation_0-logloss:0.67167
# [119]	validation_0-logloss:0.67335
# [120]	validation_0-logloss:0.67426
# [121]	validation_0-logloss:0.67519
# [122]	validation_0-logloss:0.67629
# [123]	validation_0-logloss:0.67541
# [124]	validation_0-logloss:0.67593
# [125]	validation_0-logloss:0.67752
# [126]	validation_0-logloss:0.67676
# [127]	validation_0-logloss:0.67715
# [128]	validation_0-logloss:0.67732
# [129]	validation_0-logloss:0.67781
# [130]	validation_0-logloss:0.67910
# [131]	validation_0-logloss:0.68035
# [132]	validation_0-logloss:0.68065
# [133]	validation_0-logloss:0.68110
# [134]	validation_0-logloss:0.68174
# [135]	validation_0-logloss:0.68298
# [136]	validation_0-logloss:0.68407
# [137]	validation_0-logloss:0.68394
# [138]	validation_0-logloss:0.68435
# [139]	validation_0-logloss:0.68587
# [140]	validation_0-logloss:0.68662
# [141]	validation_0-logloss:0.68790
# [142]	validation_0-logloss:0.68987
# [143]	validation_0-logloss:0.69103
# [144]	validation_0-logloss:0.69173
# [145]	validation_0-logloss:0.69175
# [146]	validation_0-logloss:0.69298
# [147]	validation_0-logloss:0.69500
# [148]	validation_0-logloss:0.69623
# [149]	validation_0-logloss:0.69785
# [150]	validation_0-logloss:0.69877
# [151]	validation_0-logloss:0.70007
# [152]	validation_0-logloss:0.70226
# [153]	validation_0-logloss:0.70349
# [154]	validation_0-logloss:0.70476
# [155]	validation_0-logloss:0.70544
# [156]	validation_0-logloss:0.70660
# [157]	validation_0-logloss:0.70669
# [158]	validation_0-logloss:0.70795
# [159]	validation_0-logloss:0.70872
# [160]	validation_0-logloss:0.70978
# [161]	validation_0-logloss:0.71093
# [162]	validation_0-logloss:0.71166
# [163]	validation_0-logloss:0.71264
# [164]	validation_0-logloss:0.71355
# [165]	validation_0-logloss:0.71462
# [166]	validation_0-logloss:0.71508
# [167]	validation_0-logloss:0.71479
# [168]	validation_0-logloss:0.71504
# [169]	validation_0-logloss:0.71598
# [170]	validation_0-logloss:0.71614
# [171]	validation_0-logloss:0.71629
# [172]	validation_0-logloss:0.71748
# [173]	validation_0-logloss:0.71859
# [174]	validation_0-logloss:0.71762
# [175]	validation_0-logloss:0.71929
# [176]	validation_0-logloss:0.72006
# [177]	validation_0-logloss:0.72019
# [178]	validation_0-logloss:0.72079
# [179]	validation_0-logloss:0.72160
# [180]	validation_0-logloss:0.72116
# [181]	validation_0-logloss:0.72167
# [182]	validation_0-logloss:0.72227
# [183]	validation_0-logloss:0.72276
# [184]	validation_0-logloss:0.72385
# [185]	validation_0-logloss:0.72605
# [186]	validation_0-logloss:0.72700
# [187]	validation_0-logloss:0.72768
# [188]	validation_0-logloss:0.72828
# [189]	validation_0-logloss:0.72721
# [190]	validation_0-logloss:0.72886
# [191]	validation_0-logloss:0.72923
# [192]	validation_0-logloss:0.73022
# [193]	validation_0-logloss:0.73092
# [194]	validation_0-logloss:0.73297
# [195]	validation_0-logloss:0.73397
# [196]	validation_0-logloss:0.73292
# [197]	validation_0-logloss:0.73303
# [198]	validation_0-logloss:0.73519
# [199]	validation_0-logloss:0.73592
# [200]	validation_0-logloss:0.73448
# [201]	validation_0-logloss:0.73500
# [202]	validation_0-logloss:0.73665
# [203]	validation_0-logloss:0.73626
# [204]	validation_0-logloss:0.73682
# [205]	validation_0-logloss:0.73735
# [206]	validation_0-logloss:0.73791
# [207]	validation_0-logloss:0.73857
# [208]	validation_0-logloss:0.73866
# [209]	validation_0-logloss:0.73808
# [210]	validation_0-logloss:0.73729
# [211]	validation_0-logloss:0.73888
# [212]	validation_0-logloss:0.73890
# [213]	validation_0-logloss:0.73921
# [214]	validation_0-logloss:0.73901
# [215]	validation_0-logloss:0.74005
# [216]	validation_0-logloss:0.73997
# [217]	validation_0-logloss:0.74041
# [218]	validation_0-logloss:0.74162
# [219]	validation_0-logloss:0.74208
# [220]	validation_0-logloss:0.74196
# [221]	validation_0-logloss:0.74197
# [222]	validation_0-logloss:0.74179
# [223]	validation_0-logloss:0.74213
# [224]	validation_0-logloss:0.74201
# [225]	validation_0-logloss:0.74360
# [226]	validation_0-logloss:0.74472
# [227]	validation_0-logloss:0.74563
# [228]	validation_0-logloss:0.74634
# [229]	validation_0-logloss:0.74632
# [230]	validation_0-logloss:0.74605
# [231]	validation_0-logloss:0.74593
# [232]	validation_0-logloss:0.74731
# [233]	validation_0-logloss:0.74818
# [234]	validation_0-logloss:0.74890
# [235]	validation_0-logloss:0.74932
# [236]	validation_0-logloss:0.74990
# [237]	validation_0-logloss:0.75185
# [238]	validation_0-logloss:0.75257
# [239]	validation_0-logloss:0.75251
# [240]	validation_0-logloss:0.75307
# [241]	validation_0-logloss:0.75346
# [242]	validation_0-logloss:0.75456
# [243]	validation_0-logloss:0.75493
# [244]	validation_0-logloss:0.75510
# [245]	validation_0-logloss:0.75525
# [246]	validation_0-logloss:0.75527
# [247]	validation_0-logloss:0.75505
# [248]	validation_0-logloss:0.75559
# [249]	validation_0-logloss:0.75560
# [250]	validation_0-logloss:0.75667
# [251]	validation_0-logloss:0.75721
# [252]	validation_0-logloss:0.75749
# [253]	validation_0-logloss:0.75830
# [254]	validation_0-logloss:0.75898
# [255]	validation_0-logloss:0.75864
# [256]	validation_0-logloss:0.75978
# [257]	validation_0-logloss:0.76078
# [258]	validation_0-logloss:0.76015
# [259]	validation_0-logloss:0.76036
# [260]	validation_0-logloss:0.76011
# [261]	validation_0-logloss:0.76030
# [262]	validation_0-logloss:0.76093
# [263]	validation_0-logloss:0.76182
# [264]	validation_0-logloss:0.76199
# [265]	validation_0-logloss:0.76193
# [266]	validation_0-logloss:0.76266
# [267]	validation_0-logloss:0.76323
# [268]	validation_0-logloss:0.76410
# [269]	validation_0-logloss:0.76442
# [270]	validation_0-logloss:0.76337
# [271]	validation_0-logloss:0.76357
# [272]	validation_0-logloss:0.76455
# [273]	validation_0-logloss:0.76511
# [274]	validation_0-logloss:0.76617
# [275]	validation_0-logloss:0.76724
# [276]	validation_0-logloss:0.76814
# [277]	validation_0-logloss:0.76854
# [278]	validation_0-logloss:0.77004
# [279]	validation_0-logloss:0.77121
# [280]	validation_0-logloss:0.77113
# [281]	validation_0-logloss:0.77150
# [282]	validation_0-logloss:0.77262
# [283]	validation_0-logloss:0.77282
# [284]	validation_0-logloss:0.77431
# [285]	validation_0-logloss:0.77506
# [286]	validation_0-logloss:0.77400
# [287]	validation_0-logloss:0.77489
# [288]	validation_0-logloss:0.77524
# [289]	validation_0-logloss:0.77465
# [290]	validation_0-logloss:0.77572
# [291]	validation_0-logloss:0.77520
# [292]	validation_0-logloss:0.77594
# [293]	validation_0-logloss:0.77626
# [294]	validation_0-logloss:0.77611
# [295]	validation_0-logloss:0.77681
# [296]	validation_0-logloss:0.77612
# [297]	validation_0-logloss:0.77738
# [298]	validation_0-logloss:0.77715
# [299]	validation_0-logloss:0.77802
# [300]	validation_0-logloss:0.77881
# [301]	validation_0-logloss:0.77964
# [302]	validation_0-logloss:0.78036
# [303]	validation_0-logloss:0.78072
# [304]	validation_0-logloss:0.78161
# [305]	validation_0-logloss:0.78279
# [306]	validation_0-logloss:0.78323
# [307]	validation_0-logloss:0.78338
# [308]	validation_0-logloss:0.78391
# [309]	validation_0-logloss:0.78389
# [310]	validation_0-logloss:0.78475
# [311]	validation_0-logloss:0.78596
# [312]	validation_0-logloss:0.78666
# [313]	validation_0-logloss:0.78611
# [314]	validation_0-logloss:0.78594
# [315]	validation_0-logloss:0.78653
# [316]	validation_0-logloss:0.78782
# [317]	validation_0-logloss:0.78775
# [318]	validation_0-logloss:0.78814
# [319]	validation_0-logloss:0.78987
# [320]	validation_0-logloss:0.78990
# [321]	validation_0-logloss:0.79087
# [322]	validation_0-logloss:0.79161
# [323]	validation_0-logloss:0.79173
# [324]	validation_0-logloss:0.79184
# [325]	validation_0-logloss:0.79276
# [326]	validation_0-logloss:0.79217
# [327]	validation_0-logloss:0.79333
# [328]	validation_0-logloss:0.79334
# [329]	validation_0-logloss:0.79392
# [330]	validation_0-logloss:0.79334
# [331]	validation_0-logloss:0.79348
# [332]	validation_0-logloss:0.79414
# [333]	validation_0-logloss:0.79500
# [334]	validation_0-logloss:0.79556
# [335]	validation_0-logloss:0.79661
# [336]	validation_0-logloss:0.79668
# [337]	validation_0-logloss:0.79855
# [338]	validation_0-logloss:0.79966
# [339]	validation_0-logloss:0.80126
# [340]	validation_0-logloss:0.80111
# [341]	validation_0-logloss:0.80180
# [342]	validation_0-logloss:0.80354
# [343]	validation_0-logloss:0.80433
# [344]	validation_0-logloss:0.80437
# [345]	validation_0-logloss:0.80496
# [346]	validation_0-logloss:0.80435
# [347]	validation_0-logloss:0.80497
# [348]	validation_0-logloss:0.80522
# [349]	validation_0-logloss:0.80597
# [350]	validation_0-logloss:0.80648
# [351]	validation_0-logloss:0.80709
# [352]	validation_0-logloss:0.80732
# [353]	validation_0-logloss:0.80736
# [354]	validation_0-logloss:0.80685
# [355]	validation_0-logloss:0.80735
# [356]	validation_0-logloss:0.80830
# [357]	validation_0-logloss:0.80970
# [358]	validation_0-logloss:0.80961
# [359]	validation_0-logloss:0.80895
# [360]	validation_0-logloss:0.80883
# [361]	validation_0-logloss:0.81062
# [362]	validation_0-logloss:0.81114
# [363]	validation_0-logloss:0.81163
# [364]	validation_0-logloss:0.81163
# [365]	validation_0-logloss:0.81229
# [366]	validation_0-logloss:0.81294
# [367]	validation_0-logloss:0.81417
# [368]	validation_0-logloss:0.81369
# [369]	validation_0-logloss:0.81452
# [370]	validation_0-logloss:0.81488
# [371]	validation_0-logloss:0.81399
# [372]	validation_0-logloss:0.81517
# [373]	validation_0-logloss:0.81563
# [374]	validation_0-logloss:0.81601
# [375]	validation_0-logloss:0.81698
# [376]	validation_0-logloss:0.81706
# [377]	validation_0-logloss:0.81827
# [378]	validation_0-logloss:0.81786
# [379]	validation_0-logloss:0.81859
# [380]	validation_0-logloss:0.81795
# [381]	validation_0-logloss:0.81847
# [382]	validation_0-logloss:0.81860
# [383]	validation_0-logloss:0.81908
# [384]	validation_0-logloss:0.81924
# [385]	validation_0-logloss:0.81951
# [386]	validation_0-logloss:0.81958
# [387]	validation_0-logloss:0.81985
# [388]	validation_0-logloss:0.82148
# [389]	validation_0-logloss:0.82307
# [390]	validation_0-logloss:0.82343
# [391]	validation_0-logloss:0.82253
# [392]	validation_0-logloss:0.82325
# [393]	validation_0-logloss:0.82292
# [394]	validation_0-logloss:0.82403
# [395]	validation_0-logloss:0.82443
# [396]	validation_0-logloss:0.82449
# [397]	validation_0-logloss:0.82479
# [398]	validation_0-logloss:0.82525
# [399]	validation_0-logloss:0.82591
# [400]	validation_0-logloss:0.82608
# [401]	validation_0-logloss:0.82639
# [402]	validation_0-logloss:0.82666
# [403]	validation_0-logloss:0.82686
# [404]	validation_0-logloss:0.82634
# [405]	validation_0-logloss:0.82598
# [406]	validation_0-logloss:0.82535
# [407]	validation_0-logloss:0.82591
# [408]	validation_0-logloss:0.82698
# [409]	validation_0-logloss:0.82714
# [410]	validation_0-logloss:0.82777
# [411]	validation_0-logloss:0.82730
# [412]	validation_0-logloss:0.82692
# [413]	validation_0-logloss:0.82745
# [414]	validation_0-logloss:0.82686
# [415]	validation_0-logloss:0.82679
# [416]	validation_0-logloss:0.82665
# [417]	validation_0-logloss:0.82696
# [418]	validation_0-logloss:0.82783
# [419]	validation_0-logloss:0.82803
# [420]	validation_0-logloss:0.82830
# [421]	validation_0-logloss:0.82919
# [422]	validation_0-logloss:0.82977
# [423]	validation_0-logloss:0.83029
# [424]	validation_0-logloss:0.83074
# [425]	validation_0-logloss:0.83053
# [426]	validation_0-logloss:0.83004
# [427]	validation_0-logloss:0.82973
# [428]	validation_0-logloss:0.83096
# [429]	validation_0-logloss:0.83124
# [430]	validation_0-logloss:0.83233
# [431]	validation_0-logloss:0.83191
# [432]	validation_0-logloss:0.83239
# [433]	validation_0-logloss:0.83281
# [434]	validation_0-logloss:0.83295
# [435]	validation_0-logloss:0.83296
# [436]	validation_0-logloss:0.83328
# [437]	validation_0-logloss:0.83382
# [438]	validation_0-logloss:0.83477
# [439]	validation_0-logloss:0.83427
# [440]	validation_0-logloss:0.83495
# [441]	validation_0-logloss:0.83443
# [442]	validation_0-logloss:0.83489
# [443]	validation_0-logloss:0.83509
# [444]	validation_0-logloss:0.83581
# [445]	validation_0-logloss:0.83526
# [446]	validation_0-logloss:0.83518
# [447]	validation_0-logloss:0.83624
# [448]	validation_0-logloss:0.83688
# [449]	validation_0-logloss:0.83726
# [15:30:31] Training finished in 1.86s
# [15:30:36] New version: v_20260204_203029
# [15:30:36] Metrics: {'accuracy': 0.656, 'f1': 0.7611111111111111, 'precision': 0.7405405405405405, 'recall': 0.7828571428571428, 'roc_auc': 0.6496761904761905}
# [15:30:36] Updated registry: ../artifacts/models/model_registry.json
# /Users/juanguillenalbarracin/anaconda3/lib/python3.10/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# Registered model 'CooperativeCreditRisk-XGBoost' already exists. Creating a new version of this model...
# Created version '2' of model 'CooperativeCreditRisk-XGBoost'.
